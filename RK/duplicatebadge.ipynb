# %%
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rr=cv2.imread('1.jpeg')
a=cv2.cvtColor(rr,cv2.COLOR_BGR2RGB)
from matplotlib.pyplot import figure
figure(figsize=(14, 10), dpi=80)
plt.imshow(a)

# %%
r1r=cv2.imread('11.jpeg')
a1=cv2.cvtColor(r1r,cv2.COLOR_BGR2RGB)
a1=cv2.rotate(a1,cv2.ROTATE_90_COUNTERCLOCKWISE)
#a=cv2.flip(a,0)

plt.imshow(a1)

# %%
width = int(a1.shape[1] * 17 / 100)
height = int(a1.shape[0] * 17 / 100)
dim = (width, height)
r = cv2.resize(a1, dim, interpolation = cv2.INTER_AREA)
plt.imshow(r)

# %%
figure(figsize=(14, 10), dpi=80)
plt.imshow(a)

# %%
b=np.array(a)
b[165:165 +r.shape[0],145:145+r.shape[1]]=r
figure(figsize=(14, 10), dpi=80)
plt.imshow(b)
